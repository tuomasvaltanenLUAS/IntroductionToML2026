# %% [markdown]
# ### Quick visualizations to see how the data looks like

# %%
import pandas as pd
import seaborn as sns

# %%
# open the raw data
df = pd.read_csv(r"data\digitraffic_weather_2024_04_08_22_22.csv")

# %%
df
# Out:
#      stationId  KASTEPISTE  KESKITUULI  ILMAN_KOSTEUS  SADE  SADESUMMA  \
# 0       1001.0         4.6         0.7          99.00   0.0        0.0
# 1       1002.0         4.7         5.3          90.00   0.0        0.0
# 2          NaN         NaN         NaN            NaN   NaN        NaN
# 3       1004.0         4.5         2.1          93.00   0.0        0.0
# 4       1005.0         6.7         2.8          93.00   0.0        0.0
# ..         ...         ...         ...            ...   ...        ...
# 531    45003.0         0.0         NaN          49.98   NaN        0.0
# 532    45004.0         1.2         NaN          96.65   NaN        2.2
# 533    45005.0         0.0         NaN         100.00   NaN        9.7
# 534    45006.0        -0.1         NaN         100.00   NaN       11.2
# 535    45007.0         0.0         NaN         100.00   NaN       14.7
#
#      SATEEN_OLOMUOTO_PWDXX  TURVALLISUUSLÄMPÖ_1  ILMAN_LÄMPÖTILA_24H_MIN  \
# ...

# %% [markdown]
# ## Let's now open to preprocessed version instead

# %%
df = pd.read_csv(r"digitraffic_weather_balanced_ver1_2026.csv")

# %%
# let's check the target variable balance
df['condition'].value_counts()
# Out:
# condition
# Normal    600
# Rain      600
# Snow      512
# Ice       415
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue="condition")
