# %% [markdown]
# ### Random Forest weather detection model (using RandomizedSearchCV to find better hyperparameters)

# %%
# WHEN OPTIMIZING PARAMETERS, ALWAYS LOCK DOWN YOUR RANDOM SEEDS
import random
import numpy as np

random_seed = 2026
random.seed(random_seed)
np.random.seed(random_seed)

# %%
# usual imports in a classic ML pipeline for Classification
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import metrics

# we can import the random forest algorithms from 
# scikit-learn's ensemble -features
from sklearn.ensemble import RandomForestClassifier

# additional metrics ONLY for classification
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# let's add some helpful features like the pipelines
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# load the data
df = pd.read_csv("digitraffic_weather_balanced_ver1_2026.csv")

# let's quickly see the first 5 rows of data
df
# Out:
#       dew_point  avg_wind    humidity      rain  rain_sum  snow_depth  \
# 0    -12.700000  5.500000   47.000000  0.000000   0.00000         0.0
# 1    -10.584339  3.856224   82.055339  1.155024   2.57065         0.0
# 2     -3.200000  2.100000   96.000000  4.000000   2.10000         0.0
# 3      0.400000  0.900000   98.000000  0.000000   0.70000         0.0
# 4    -10.154048  1.549590   86.478021  0.437110   0.00000         0.0
# ...         ...       ...         ...       ...       ...         ...
# 2122  -2.500000  2.600000   97.000000  4.000000   1.30000        16.0
# 2123   3.500000  2.100000   59.000000  0.000000   0.00000         0.0
# 2124   0.500000  1.400000   93.000000  1.000000   1.40000         0.0
# 2125  -2.700000  5.600000   92.000000  4.000000   0.80000         4.0
# 2126   5.100000  1.500000  100.000000  0.000000   0.20000         0.0
#
#       rain_amount  snow_amount  ice_measure  friction  ice_frequency  \
# 0        0.000000      0.00000     0.000000  0.820000          487.0
# 1        0.010964      0.16092     0.000000  0.806557          105.0
# 2        0.000000      0.34000     0.110000  0.380000          112.0
# 3        0.020000      0.00000     0.000000  0.820000          465.0
# 4        0.180977      0.00000     0.262158  0.686309          105.0
# ...           ...          ...          ...       ...            ...
# 2122     0.000000      0.18000     0.170000  0.260000          110.0
# 2123     0.000000      0.00000     0.000000  0.820000          112.0
# 2124     0.590000      0.00000     0.000000  0.660000          115.0
# 2125     0.280000      0.00000     0.000000  0.710000          112.0
# 2126     0.170000      0.00000     0.000000  0.760000          112.0
#
#       mean_temperature condition
# 0            -8.800000    Normal
# 1            -5.204363       Ice
# 2            -8.100000      Snow
# 3             4.550000      Rain
# 4            -2.060633       Ice
# ...                ...       ...
# 2122         -5.800000      Snow
# 2123          6.400000      Rain
# 2124         -1.000000      Rain
# 2125         -0.700000      Snow
# 2126          0.500000      Rain
#
# [2127 rows x 13 columns]

# %%
# check duplicates, we have a few
df.duplicated().sum()
# Out:
# np.int64(36)

# %%
# drop the duplicates
df = df.drop_duplicates()

# %%
# condition is our target variable, let's check the balance
df['condition'].value_counts()
# Out:
# condition
# Rain      595
# Normal    570
# Snow      511
# Ice       415
# Name: count, dtype: int64

# %%
# no missing values anywhere
df.isna().sum()
# Out:
# dew_point           0
# avg_wind            0
# humidity            0
# rain                0
# rain_sum            0
# snow_depth          0
# rain_amount         0
# snow_amount         0
# ice_measure         0
# friction            0
# ice_frequency       0
# mean_temperature    0
# condition           0
# dtype: int64

# %%
# this is technically not required in most algorithms
# but for easier testing, let's encode the target
mapping = {"Ice": 0, "Normal": 1, "Rain": 2, "Snow": 3}
df['condition'] = df['condition'].map(mapping)

# save also the labels for easier metrics and model usage with new data
labels = ["Ice", "Normal", "Rain", "Snow"]
# Out:
# C:\Users\tuomas.valtanen\AppData\Local\Temp\ipykernel_5112\2731686899.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['condition'] = df['condition'].map(mapping)

# %% [markdown]
# ### X/y and train/test -splits

# %%
# first step, we split our data into SUPPORT variables and the TARGET variable
# X => support variables, y => target variable

# X => list of support variables the model uses 
# while predicting the target variable with the model
X = df.drop("condition", axis=1)

# our target variable is y
y = df['condition']

# %%
# secondly, train/test -split with scikit-learn's helper function
# 0.3 for testing => 30% of data is reserved for testing purposes
# and based on that => it's deduced that 70% will be in the training data

# you can also define the random state, which is sometimes useful
# if you want to "lock down" all the randomness in order to get same results every time
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1995)

# %% [markdown]
# ### Let's try to find better hyperparameters

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import randint, uniform
# from sklearn.pipeline import Pipeline

# # Create the RandomForestClassifier model
# model = RandomForestClassifier()

# # Define the parameter grid for RandomizedSearchCV
# param_dist = {
#     'rf__n_estimators': randint(25, 400),         # Number of trees in the forest
#     'rf__max_depth': randint(3, 75)           # Maximum depth of the tree
# }

# # so that we can use both StandardScaler + SVR in GridSearchCV
# pipe = Pipeline([
#     ('scaler', StandardScaler()),
#     ('rf', RandomForestClassifier())
# ])

# # Create RandomizedSearchCV with 5-fold cross-validation
# random_search = RandomizedSearchCV(estimator=pipe, 
#                                    param_distributions=param_dist,
#                                    n_iter=750,        # Number of parameter settings to sample
#                                    cv=3,              # Cross-validation splitting strategy
#                                    random_state=42,   # For reproducibility
#                                    n_jobs=-1,         # Use all CPUs
#                                    verbose=1)         # Display progress

# # Fit the random search to the data
# random_search.fit(X, y)

# # Get the best parameters and score
# print("Best parameters found: ", random_search.best_params_)
# print("Best score: ", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 750 candidates, totalling 2250 fits
# c:\Users\tuomas.valtanen\introtoml2026lectures\IntroductionToML2026\.venv\Lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best parameters found:  {'rf__max_depth': 62, 'rf__n_estimators': 301}
# Best score:  0.9320899091343855

# %% [markdown]
# ### Train the model

# %%
# create the model and train it with the data
# model = LogisticRegression()

# Pipeline is super helpful here, since we can integrate the scaler
# before the model, no need to manually scale anything
model = make_pipeline(StandardScaler(), RandomForestClassifier(max_depth=62, n_estimators=301))
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=62, n_estimators=301))])

# %% [markdown]
# ### Classification error metrics

# %%
# we need to create test predictions based on our earlier reserved test dataset
# this data has never been seen by the model by now
predictions = model.predict(X_test)

# %% [markdown]
# Random Forest with default settings, accuracies are usualy between 91-93%

# %%
# print the classification report based on true values and predictions
print(classification_report(y_test, predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97        96
#            1       0.91      0.92      0.91       157
#            2       0.90      0.86      0.88       143
#            3       0.94      0.98      0.96       127
#
#     accuracy                           0.93       523
#    macro avg       0.93      0.93      0.93       523
# weighted avg       0.93      0.93      0.93       523
#
#
# Model overall accuracy: 92.73%

# %%
# see the confusion matrix
sns.heatmap(confusion_matrix(y_test, predictions), annot=True, fmt='g',
            xticklabels=labels, yticklabels=labels)
# Out:
# <Axes: >

# %%
# The AUC score is a super sensitive metric
# you often get low scores, even 0.5

# in binary logistic regression, AUC values are often interpreted as follows:
# A binary classifier is useful only when it achieves ROC-AUC score greater than 0.5 and as near to 1 as possible. 
# If a classifier yields a score less than 0.5, it simply means that the model is performing worse 
# than a random classifier, and therefore is useless.

# In multinomial logistic regression , AUC values are often interpreted as follows: 
# 0.5-0.6 (failed)
# 0.6-0.7 (worthless)
# 0.7-0.8 (poor)
# 0.8-0.9 (good)
# > 0.9 (excellent)

# basically 0.5 means you could get the same result with just random guessing
roc_auc_score(y_test, model.predict_proba(X_test), multi_class="ovr")
# Out:
# 0.9901770059438687

# %% [markdown]
# ### Using the model in practice

# %%
df.columns
# Out:
# Index(['dew_point', 'avg_wind', 'humidity', 'rain', 'rain_sum', 'snow_depth',
#        'rain_amount', 'snow_amount', 'ice_measure', 'friction',
#        'ice_frequency', 'mean_temperature', 'condition'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    dew_point  avg_wind   humidity      rain  rain_sum  snow_depth  \
# 0 -12.700000  5.500000  47.000000  0.000000   0.00000         0.0
# 1 -10.584339  3.856224  82.055339  1.155024   2.57065         0.0
# 2  -3.200000  2.100000  96.000000  4.000000   2.10000         0.0
#
#    rain_amount  snow_amount  ice_measure  friction  ice_frequency  \
# 0     0.000000      0.00000         0.00  0.820000          487.0
# 1     0.010964      0.16092         0.00  0.806557          105.0
# 2     0.000000      0.34000         0.11  0.380000          112.0
#
#    mean_temperature  condition
# 0         -8.800000          1
# 1         -5.204363          0
# 2         -8.100000          3

# %%
# usually in GUI application we save the model-object / variable into a file (by using joblib-module)
# and in the GUI application => we load the saved model from the file
# and use the model just like here below

# map all the variables from the user
# into a Python dictionary
# the variable names have to match with the original dataset

# -3.200000	2.100000	96.000000	4.000000	2.10000	0.0	0.000000	0.34000	0.11	0.380000	112.0	-8.100000	
tester_row = {
    'dew_point': -3.2, 
    'avg_wind': 2.1, 
    'humidity': 96.0, 
    'rain': 4.0, 
    'rain_sum': 2.1, 
    'snow_depth': 0.0,
    'rain_amount': 0.0, 
    'snow_amount': 0.34, 
    'ice_measure': 0.11, 
    'friction': 0.38,
    'ice_frequency': 112.0, 
    'mean_temperature': -8.1
}

# convert to pandas format
tester_row = pd.DataFrame([tester_row])

# %%
print("All probabilities by category:")
print(labels)
print(model.predict_proba(tester_row))
print()

print("Weather prediction based on the given data:")
result = labels[model.predict(tester_row)[0]]
print(result)
print("-------------------")
# Out:
# All probabilities by category:
# ['Ice', 'Normal', 'Rain', 'Snow']
# [[0.10631229 0.00332226 0.02657807 0.86378738]]
#
# Weather prediction based on the given data:
# Snow
# -------------------

# %%
# save the model into a file, check out the file
# => weather_control_model1
from joblib import dump
dump(model, "weathercontrolmodel1.joblib")
# Out:
# ['weathercontrolmodel1.joblib']
