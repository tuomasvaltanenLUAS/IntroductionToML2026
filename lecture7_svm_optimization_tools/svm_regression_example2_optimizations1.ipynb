# %% [markdown]
# ### SVR regression, housing data test with the TransformedTargetRegressor

# %% [markdown]
# **Trying GridSearchCV here too to find more optimal parameters.**

# %%
# usual imports in a classic ML pipeline for Regression
# pip install numpy
# pip install pandas
# pip install seaborn
# pip install scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import pipelines, SVM etc.
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# this helps us with all the scaling, both X and y are scaled
# automatically!
from sklearn.compose import TransformedTargetRegressor

# %%
# load the data
df = pd.read_csv("Housing.csv")

# let's quickly see the first 5 rows of data
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# 5              no             yes        2      yes   semi-furnished
# 6              no             yes        2      yes   semi-furnished
# 7              no              no        0       no      unfurnished
# 8              no             yes        2      yes        furnished
# 9              no             yes        1      yes      unfurnished

# %% [markdown]
# ### STEP 2: Handle missing/duplicate values and HANDLE ALL CATEGORICAL VARIABLES CORRECTLY

# %% [markdown]
# **Case 1: Binary variables (only two options)**

# %% [markdown]
# If your dataset does not have any binary variables => remove/disable the code cell below.

# %%
# this just converts the value of column to 0 or 1
# factorize in pandas works too, but only one column at a time
from sklearn.preprocessing import LabelEncoder
variables = ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']
encoder = LabelEncoder()
df[variables] = df[variables].apply(encoder.fit_transform)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %% [markdown]
# **Case 2: Ordinal variables (categories that have an order/rank -> can be compared)**

# %%
# we don't have ordinal categories here, so we'll skip these, check the diamonds example later for this

# %% [markdown]
# **Case 3: Nominal categories (categories that can't be compared numerically)**

# %%
# this makes multiple columns with the variable (Separate for yes/no)
from sklearn.preprocessing import OneHotEncoder
variables = ['furnishingstatus']

# use encoder
encoder = OneHotEncoder(sparse_output=False).set_output(transform="pandas")
one_hot_encoded = encoder.fit_transform(df[variables]).astype(int)
df = pd.concat([df,one_hot_encoded],axis=1).drop(columns=variables)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           1                                0
#
#    furnishingstatus_unfurnished
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0

# %%
# see the materials (Rovaniemi/Oulu/Helsinki), we can make a small optimization
# => remove the last new boolean variable, since it's going to be represented
# by a straight line of zeroes
df = df.drop("furnishingstatus_unfurnished", axis=1)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus_furnished  furnishingstatus_semi-furnished
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
# 3                           1                                0
# 4                           1                                0

# %% [markdown]
# ### STEP 3: Data is good to go (all numbers) => train model etc.

# %%
# first step, we split our data into SUPPORT variables and the TARGET variable
# X => support variables, y => target variable

# X => list of support variables the model uses 
# while predicting the target variable with the model
X = df.drop("price", axis=1)

# our target variable is y
y = df['price']

# %% [markdown]
# **IMPORTANT WHEN OPTIMIZING PARAMETERS!**
#
# Always lock down randomness in your algorithm and data so that your baseline remains the same. If you don't do this, you never know if the model improved because of the parameters or just sheer luck!

# %% [markdown]
# Here we only lock down train/test-split. We usually also lock down NumPy random seed + others!

# %%
# secondly, train/test -split with scikit-learn's helper function
# 0.3 for testing => 30% of data is reserved for testing purposes
# and based on that => it's deduced that 70% will be in the training data

# you can also define the random state, which is sometimes useful
# if you want to "lock down" all the randomness in order to get same results every time
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1718951)

# %% [markdown]
# **Finding optimal SVM parameters -> GridSearchCV**
#
# **NOTE: poly-kernel is super heavy to train via GridSearchCV, rbf and linear are more light-weight!**

# %% [markdown]
# **Idea to improve this:** use a Pipeline also here in the GridSearchCV in order to have the same situation here as in the actual model training.

# %%
from sklearn.model_selection import GridSearchCV

# initialize testable parameters
# NOTE! all algorithms do not support all parameters
# see notes below which you can use with which
# # SVR() -> C, kernel, degree (if using poly), gamma, C, epsilon, max_iter
param_grid = {
    'C': [0.1, 0.25, 0.5, 1, 1.25, 1.5],
    'epsilon': [0.075, 0.1, 0.125],
    'gamma': [1, 0.25, 0.1, 0.05, 0.01], 
    'kernel': ['rbf']
}

# start finding the optimal parameters with GridSearchCV!
test_model = GridSearchCV(svm.SVR(), param_grid, verbose=3)
test_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END C=0.1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=0.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=0.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=0.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=0.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=0.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.25, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.075, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.075, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.075, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.075, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.075, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.1, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.1, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.1, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.125, gamma=1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.125, gamma=0.25, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.125, gamma=0.1, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.125, gamma=0.05, kernel=rbf;, score=-0.097 total time=   0.0s
# [CV 1/5] END C=1.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.018 total time=   0.0s
# [CV 2/5] END C=1.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.114 total time=   0.0s
# [CV 3/5] END C=1.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.115 total time=   0.0s
# [CV 4/5] END C=1.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 5/5] END C=1.5, epsilon=0.125, gamma=0.01, kernel=rbf;, score=-0.097 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 0.25, 0.5, 1, 1.25, 1.5],
#                          'epsilon': [0.075, 0.1, 0.125],
#                          'gamma': [1, 0.25, 0.1, 0.05, 0.01],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
test_model.best_params_
# Out:
# {'C': 1.5, 'epsilon': 0.125, 'gamma': 0.01, 'kernel': 'rbf'}

# %% [markdown]
# **We'll use Pipeline + TransformedTargetRegressor in order to scale both X and y -automatically**

# %%
# create the model and train it with the data
# use pipeline to scale the X-values automatically with StandardScaler
pipeline = make_pipeline(
    StandardScaler(), 
    svm.SVR(C=1.5, epsilon=0.125, gamma=0.01, kernel='rbf')
)

# use TransformedTargetRegressor to automatically scale y
# and pipelines above to automatically scale X
model = TransformedTargetRegressor(
    regressor=pipeline,
    transformer=MinMaxScaler()
)

# train the model
model.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('standardscaler',
#                                                       StandardScaler()),
#                                                      ('svr',
#                                                       SVR(C=1.5, epsilon=0.125,
#                                                           gamma=0.01))]),
#                            transformer=MinMaxScaler())

# %%
# we need to create test predictions based on our earlier reserved test dataset
# this data has never been seen by the model by now
predictions = model.predict(X_test)

# %%
# let's plot how far the predictions are from the real target values (y)
# in the test dataset

# if the values follow a diagonal line (from bottom left to top right)
# => we have good predictions with the model
# we basically compare the predicted values to the actual true values 
# and compare the differences
plt.scatter(y_test, predictions)
plt.show()

# %%
# MAE = Mean average error
mae = metrics.mean_absolute_error(y_test, predictions)
print("MAE:")
print(f"{round(mae, 2)} $")

# MSE = Mean squared error
mse = metrics.mean_squared_error(y_test, predictions)
print("\nMSE:")
print(f"{round(mse, 2)} $^2")

# RMSE = Root Mean Squared Error
rmse = np.sqrt(mse)
print("\nRMSE:")
print(f"{round(rmse, 2)} $")

# R-square (or R2) - how well the model describes the original dataset
# 1 => model describes the data perfectly
# 0 => model doesn't describe the data at all
r2 = metrics.r2_score(y_test, predictions)
print("\nR-squared:")
print(f"{round(r2, 2)}")

# SCALED VERSIONS OF THE METRICS, only use MAE and RMSE
y_test_scaled = model.transformer_.transform(y_test.values.reshape(-1, 1)).ravel()
predictions_scaled = model.transformer_.transform(predictions.reshape(-1, 1)).ravel()

# calculate the scaled MAE and RMSE
mae_scaled = metrics.mean_absolute_error(y_test_scaled, predictions_scaled)
rmse_scaled = np.sqrt(metrics.mean_squared_error(y_test_scaled, predictions_scaled))

print(f"\nMAE scaled: {round(mae_scaled, 2)}")
print(f"\nRMSE scaled: {round(rmse_scaled, 2)}")
# Out:
# MAE:
# 805627.72 $
#
# MSE:
# 979885020572.2 $^2
#
# RMSE:
# 989891.42 $
#
# R-squared:
# 0.61
#
# MAE scaled: 0.07
#
# RMSE scaled: 0.09

# %%
# if the prediction distribution is far from standard normal distritbuion
# then the model is not probably good enough
# distplot is deprecated and will be removed in future seaborn versions
# but not direct replacement has been created so far
sns.distplot((y_test - predictions))
plt.show()
plt.close()
# Out:
# C:\Users\tuomas.valtanen\AppData\Local\Temp\ipykernel_23980\2920752686.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test - predictions))

# %%
X.columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea',
#        'furnishingstatus_furnished', 'furnishingstatus_semi-furnished'],
#       dtype='str')

# %%
# usually in GUI application we save the model-object / variable into a file (by using joblib-module)
# and in the GUI application => we load the saved model from the file
# and use the model just like here below

# map all the variables from the user
# into a Python dictionary
# the variable names have to match with the original dataset
tester_row = {
    'area': 3500, 
    'bedrooms': 3, 
    'bathrooms': 1, 
    'stories': 1, 
    'mainroad': 0, 
    'guestroom': 1,
    'basement': 1, 
    'hotwaterheating': 1, 
    'airconditioning': 1, 
    'parking': 5, 
    'prefarea': 0,
    'furnishingstatus_furnished': 0, 
    'furnishingstatus_semi-furnished': 0
}

# convert to pandas format
tester_row = pd.DataFrame([tester_row])

# %% [markdown]
# **No need to invert scaling here, Pipeline + TransformedTargetRegressor scale X/y -automatically!**

# %%
# get the output/result from the model
# based on the user's given new data (above code cell)
result = model.predict(tester_row)[0]

print()
print(f"Predicted price for this house:")
print(f"$ {round(float(result), 2)}")
print("----------------------------")
# Out:
# Predicted price for this house:
# $ 6594032.29
# ----------------------------
