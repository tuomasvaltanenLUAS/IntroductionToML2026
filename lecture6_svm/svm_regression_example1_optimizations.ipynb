# %% [markdown]
# ### SVM regression - example 1 - Work experience vs. yearly salary, AUTOMATIC SCALING

# %% [markdown]
# ### USE THIS TEMPLATE FOR YOUR EXERCISE PROJECT

# %%
# usual imports in a classic ML pipeline for Regression
# pip install numpy
# pip install pandas
# pip install seaborn
# pip install scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.compose import TransformedTargetRegressor

# %% [markdown]
# ### STEP 1 - Load the data

# %%
# load the data
csv_path = "https://raw.githubusercontent.com/mk-gurucharan/Regression/master/Salary_Data.csv"
df = pd.read_csv(csv_path)

# let's quickly see the first 5 rows of data
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# **STEP 2: Basic data checks, duplicates or missing values (NaN)?**

# %%
# do we have missing values? apparently not
# dataset can't have any missing values when passing the data
# to the machine learning algorithm
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# do we have duplicates?
int(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **All data is now prepared and in numeric format (this data didn't have any categories)**

# %% [markdown]
# ### STEP 3: X/y and train/test -split

# %%
# first step, we split our data into SUPPORT variables and the TARGET variable
# X => support variables, y => target variable

# X => list of support variables the model uses 
# while predicting the target variable with the model
X = df[['YearsExperience']]

# our target variable is y
y = df['Salary']

# %%
# secondly, train/test -split with scikit-learn's helper function
# 0.3 for testing => 30% of data is reserved for testing purposes
# and based on that => it's deduced that 70% will be in the training data

# you can also define the random state, which is sometimes useful
# if you want to "lock down" all the randomness in order to get same results every time
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.model_selection import GridSearchCV

# initialize testable parameters
# NOTE! all algorithms do not support all parameters
# see notes below which you can use with which
param_grid = {
    'C': [0.1, 0.5, 1, 1.25, 1.5, 2.0],
    'gamma': [1, 0.25, 0.1, 0.05, 0.01], 
}

# start finding the optimal parameters with GridSearchCV!
test_model = GridSearchCV(svm.SVR(kernel="rbf"), param_grid, refit=True, verbose=3)
test_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END ...................C=0.1, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...................C=0.1, gamma=1;, score=-0.001 total time=   0.0s
# [CV 4/5] END ...................C=0.1, gamma=1;, score=-0.309 total time=   0.0s
# [CV 5/5] END ...................C=0.1, gamma=1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.25;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.25;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.25;, score=-0.552 total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.1;, score=-0.192 total time=   0.0s
# [CV 2/5] END .................C=0.1, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=0.1;, score=-0.001 total time=   0.0s
# [CV 4/5] END .................C=0.1, gamma=0.1;, score=-0.309 total time=   0.0s
# [CV 5/5] END .................C=0.1, gamma=0.1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.05;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.05;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.05;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.05;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.1, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.1, gamma=0.01;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.01;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.01;, score=-0.552 total time=   0.0s
# [CV 1/5] END ...................C=0.5, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...................C=0.5, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...................C=0.5, gamma=1;, score=-0.001 total time=   0.0s
# [CV 4/5] END ...................C=0.5, gamma=1;, score=-0.309 total time=   0.0s
# [CV 5/5] END ...................C=0.5, gamma=1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.5, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.25;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.25;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.25;, score=-0.552 total time=   0.0s
# [CV 1/5] END .................C=0.5, gamma=0.1;, score=-0.192 total time=   0.0s
# [CV 2/5] END .................C=0.5, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END .................C=0.5, gamma=0.1;, score=-0.001 total time=   0.0s
# [CV 4/5] END .................C=0.5, gamma=0.1;, score=-0.309 total time=   0.0s
# [CV 5/5] END .................C=0.5, gamma=0.1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.5, gamma=0.05;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.05;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.05;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.05;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=0.5, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.01;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.01;, score=-0.309 total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.01;, score=-0.552 total time=   0.0s
# [CV 1/5] END .....................C=1, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END .....................C=1, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END .....................C=1, gamma=1;, score=-0.001 total time=   0.0s
# [CV 4/5] END .....................C=1, gamma=1;, score=-0.309 total time=   0.0s
# [CV 5/5] END .....................C=1, gamma=1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.25;, score=-0.000 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.25;, score=-0.309 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.25;, score=-0.552 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...................C=1, gamma=0.1;, score=-0.000 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=0.1;, score=-0.308 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.1;, score=-0.551 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.05;, score=-0.192 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.05;, score=-0.000 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.05;, score=-0.308 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.05;, score=-0.551 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.01;, score=-0.001 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.01;, score=-0.308 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.01;, score=-0.552 total time=   0.0s
# [CV 1/5] END ..................C=1.25, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ..................C=1.25, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ..................C=1.25, gamma=1;, score=-0.001 total time=   0.0s
# [CV 4/5] END ..................C=1.25, gamma=1;, score=-0.309 total time=   0.0s
# [CV 5/5] END ..................C=1.25, gamma=1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ...............C=1.25, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...............C=1.25, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...............C=1.25, gamma=0.25;, score=-0.000 total time=   0.0s
# [CV 4/5] END ...............C=1.25, gamma=0.25;, score=-0.308 total time=   0.0s
# [CV 5/5] END ...............C=1.25, gamma=0.25;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=1.25, gamma=0.1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=1.25, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=1.25, gamma=0.1;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=1.25, gamma=0.1;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=1.25, gamma=0.1;, score=-0.551 total time=   0.0s
# [CV 1/5] END ...............C=1.25, gamma=0.05;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...............C=1.25, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...............C=1.25, gamma=0.05;, score=-0.000 total time=   0.0s
# [CV 4/5] END ...............C=1.25, gamma=0.05;, score=-0.308 total time=   0.0s
# [CV 5/5] END ...............C=1.25, gamma=0.05;, score=-0.551 total time=   0.0s
# [CV 1/5] END ...............C=1.25, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...............C=1.25, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...............C=1.25, gamma=0.01;, score=-0.001 total time=   0.0s
# [CV 4/5] END ...............C=1.25, gamma=0.01;, score=-0.308 total time=   0.0s
# [CV 5/5] END ...............C=1.25, gamma=0.01;, score=-0.552 total time=   0.0s
# [CV 1/5] END ...................C=1.5, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...................C=1.5, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...................C=1.5, gamma=1;, score=-0.001 total time=   0.0s
# [CV 4/5] END ...................C=1.5, gamma=1;, score=-0.309 total time=   0.0s
# [CV 5/5] END ...................C=1.5, gamma=1;, score=-0.552 total time=   0.0s
# [CV 1/5] END ................C=1.5, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=1.5, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=1.5, gamma=0.25;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=1.5, gamma=0.25;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=1.5, gamma=0.25;, score=-0.551 total time=   0.0s
# [CV 1/5] END .................C=1.5, gamma=0.1;, score=-0.192 total time=   0.0s
# [CV 2/5] END .................C=1.5, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END .................C=1.5, gamma=0.1;, score=-0.000 total time=   0.0s
# [CV 4/5] END .................C=1.5, gamma=0.1;, score=-0.308 total time=   0.0s
# [CV 5/5] END .................C=1.5, gamma=0.1;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=1.5, gamma=0.05;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=1.5, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=1.5, gamma=0.05;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=1.5, gamma=0.05;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=1.5, gamma=0.05;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=1.5, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=1.5, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=1.5, gamma=0.01;, score=-0.001 total time=   0.0s
# [CV 4/5] END ................C=1.5, gamma=0.01;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=1.5, gamma=0.01;, score=-0.552 total time=   0.0s
# [CV 1/5] END ...................C=2.0, gamma=1;, score=-0.192 total time=   0.0s
# [CV 2/5] END ...................C=2.0, gamma=1;, score=-0.095 total time=   0.0s
# [CV 3/5] END ...................C=2.0, gamma=1;, score=-0.000 total time=   0.0s
# [CV 4/5] END ...................C=2.0, gamma=1;, score=-0.308 total time=   0.0s
# [CV 5/5] END ...................C=2.0, gamma=1;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=2.0, gamma=0.25;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=0.25;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=0.25;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=2.0, gamma=0.25;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=2.0, gamma=0.25;, score=-0.551 total time=   0.0s
# [CV 1/5] END .................C=2.0, gamma=0.1;, score=-0.191 total time=   0.0s
# [CV 2/5] END .................C=2.0, gamma=0.1;, score=-0.095 total time=   0.0s
# [CV 3/5] END .................C=2.0, gamma=0.1;, score=-0.000 total time=   0.0s
# [CV 4/5] END .................C=2.0, gamma=0.1;, score=-0.308 total time=   0.0s
# [CV 5/5] END .................C=2.0, gamma=0.1;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=2.0, gamma=0.05;, score=-0.191 total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=0.05;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=0.05;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=2.0, gamma=0.05;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=2.0, gamma=0.05;, score=-0.551 total time=   0.0s
# [CV 1/5] END ................C=2.0, gamma=0.01;, score=-0.192 total time=   0.0s
# [CV 2/5] END ................C=2.0, gamma=0.01;, score=-0.095 total time=   0.0s
# [CV 3/5] END ................C=2.0, gamma=0.01;, score=-0.000 total time=   0.0s
# [CV 4/5] END ................C=2.0, gamma=0.01;, score=-0.308 total time=   0.0s
# [CV 5/5] END ................C=2.0, gamma=0.01;, score=-0.552 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 0.5, 1, 1.25, 1.5, 2.0],
#                          'gamma': [1, 0.25, 0.1, 0.05, 0.01]},
#              verbose=3)

# %%
# print the best combination of the parameters
test_model.best_params_
# Out:
# {'C': 2.0, 'gamma': 0.1}

# %% [markdown]
# ### STEP 4: Create and train the ML model

# %%
# create the model and train it with the data
# use pipeline to scale the X-values automatically with StandardScaler
pipeline = make_pipeline(StandardScaler(), svm.SVR(C=2, gamma=0.1))

model = TransformedTargetRegressor(
    regressor=pipeline,
    transformer=MinMaxScaler()
)

model.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('standardscaler',
#                                                       StandardScaler()),
#                                                      ('svr',
#                                                       SVR(C=2, gamma=0.1))]),
#                            transformer=MinMaxScaler())

# %% [markdown]
# ### STEP 5: Error and performance metrics

# %%
# we need to create test predictions based on our earlier reserved test dataset
# this data has never been seen by the model by now

# THESE PREDICTIONS ARE IN SCALED FORMAT
predictions = model.predict(X_test)

# %%
# let's plot how far the predictions are from the real target values (y)
# in the test dataset

# if the values follow a diagonal line (from bottom left to top right)
# => we have good predictions with the model
# we basically compare the predicted values to the actual true values 
# and compare the differences
plt.scatter(y_test, predictions)
plt.show()

# %%
# MAE = Mean average error
mae = metrics.mean_absolute_error(y_test, predictions)
print("MAE:")
print(f"{round(mae, 2)} $")

# MSE = Mean squared error
mse = metrics.mean_squared_error(y_test, predictions)
print("\nMSE:")
print(f"{round(mse, 2)} $^2")

# RMSE = Root Mean Squared Error
rmse = np.sqrt(mse)
print("\nRMSE:")
print(f"{round(rmse, 2)} $")

# R-square (or R2) - how well the model describes the original dataset
# 1 => model describes the data perfectly
# 0 => model doesn't describe the data at all
r2 = metrics.r2_score(y_test, predictions)
print("\nR-squared:")
print(f"{round(r2, 2)}")

# SCALED VERSIONS OF THE METRICS, only use MAE and RMSE
y_test_scaled = model.transformer_.transform(y_test.values.reshape(-1, 1)).ravel()
predictions_scaled = model.transformer_.transform(predictions.reshape(-1, 1)).ravel()

mae_scaled = metrics.mean_absolute_error(y_test_scaled, predictions_scaled)
rmse_scaled = np.sqrt(metrics.mean_squared_error(y_test_scaled, predictions_scaled))

print(f"\nMAE scaled: {mae_scaled}")
print(f"\nRMSE scaled: {rmse_scaled}")
# Out:
# MAE:
# 3665.57 $
#
# MSE:
# 21305628.9 $^2
#
# RMSE:
# 4615.8 $
#
# R-squared:
# 0.97
#
# MAE scaled: 0.04413796106171616
#
# RMSE scaled: 0.055579930714376884

# %%
# if the prediction distribution is far from standard normal distritbuion
# then the model is not probably good enough
# distplot is deprecated and will be removed in future seaborn versions
# but not direct replacement has been created so far
sns.distplot((y_test - predictions))
plt.show()
plt.close()
# Out:
# C:\Users\tuomas.valtanen\AppData\Local\Temp\ipykernel_22644\2920752686.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test - predictions))

# %% [markdown]
# ### STEP 6: Testing/using the model in practice (inference)

# %%
# usually in GUI application we save the model-object / variable into a file (by using joblib-module)
# and in the GUI application => we load the saved model from the file
# and use the model just like here below

# this variable could be connected to a user interface (textbox, slider etc.)
test_experience = 9

# map all the variables from the user
# into a Python dictionary
# the variable names have to match with the original dataset
tester_row = {
    "YearsExperience": test_experience
}

# convert to pandas format
tester_row = pd.DataFrame([tester_row])

# %%
# get the output/result from the model
# based on the user's given new data (above code cell)
result = model.predict(tester_row)[0]

print()
print(f"Predicted salary with {test_experience} years of work experience:")
print(f"$ {round(float(result), 2)}")
print("----------------------------")
# Out:
# Predicted salary with 9 years of work experience:
# $ 110371.48
# ----------------------------
